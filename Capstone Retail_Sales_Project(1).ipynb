# %%
import pandas as pd
import matplotlib.pyplot as plt
class RetailSalesAnalyzer:
  def __init__(self):
    self.data = pd.read_csv('MyDrive/Colab Notebooks/retail_sales.csv')
    self.data['Date'] = pd.to_datetime(self.data['Date'])

  def data_clean(self):
    self.data.dropna(inplace=True)

# %%
def total_sales_per_product(self):
  return self.Data.groupby('Product')['Sales'].sum()

# %%
def best_selling_product(self):
  return self.total_sales_per_product().sort_values(ascending=False).index[0]

# %%
def average_daily_sales(self):
  return sales.data['Sales'].mean()

# %%
def plot_sales_trend(self):
  self.data.groupby('Date')['Sales'].sum().plot(lind='line')
  plt.title('Sales Trend Over Time')
  plt.xlabel('Date')
  plt.ylabel('Total Sales')
  plt.show()

# %%
def plot_sales_per_product(self):
  self.total_sales_per_product().plot(kind='bar')
  plt.title('Sales per Product')
  plt.xlabel('Product')
  plt.ylabel('total Sales')
  plt.show()

# %%
import pandas as pd
import matplotlib.pyplot as plt

class RetailSalesAnalyzer:
    def __init__(self, data):  # Add an initializer to set the 'data' attribute
        self.data = data

    def total_sales_per_product(self):
        return self.data.groupby('Product')['Sales'].sum()

    def best_selling_product(self):
        return self.total_sales_per_product().sort_values(ascending=False).index[0]

    def average_daily_sales(self):
        return self.data['Sales'].mean()

    def plot_sales_trend(self):
        self.data.groupby('Date')['Sales'].sum().plot(kind='line')
        plt.title('Sales Trend over Time')
        plt.xlabel('Date')
        plt.ylabel('Total Sales')
        plt.show()

    def plot_sales_per_product(self):
        self.total_sales_per_product().plot(kind='bar')
        plt.title('Sales per Product')
        plt.xlabel('Product')
        plt.ylabel('Total Sales')
        plt.show()

# %%
import pandas as pd
import matplotlib.pyplot as plt

# Sample data, replace this with your actual data
data = pd.DataFrame({
    'Date': ['2023-01-01', '2023-01-01', '2023-01-02', '2023-01-02'],
    'Product': ['A', 'B', 'A', 'C'],
    'Sales': [100, 150, 120, 200]
})

class RetailSalesAnalyzer:
    def __init__(self, data):
        self.data = data

    def total_sales_per_product(self):
        return self.data.groupby('Product')['Sales'].sum()

    def best_selling_product(self):
        return self.total_sales_per_product().sort_values(ascending=False).index[0]

    def average_daily_sales(self):
        return self.data['Sales'].mean()

    def plot_sales_trend(self):
        self.data.groupby('Date')['Sales'].sum().plot(kind='line')
        plt.title('Sales Trend over Time')
        plt.xlabel('Date')
        plt.ylabel('Total Sales')
        plt.show()

    def plot_sales_per_product(self):
        self.total_sales_per_product().plot(kind='bar')
        plt.title('Sales per Product')
        plt.xlabel('Product')
        plt.ylabel('Total Sales')
        plt.show()

# Create an instance of the class, passing your sales data
analyzer = RetailSalesAnalyzer(data)  # Pass the 'data' argument here

print('Total Sales per Product: \n',analyzer.total_sales_per_product())
print('Best Selling Product: ',analyzer.best_selling_product())
print('Average Daily Sales:',analyzer.average_daily_sales())
analyzer.plot_sales_trend()
# Out:
# Total Sales per Product:
#  Product
# A    220
# B    150
# C    200
# Name: Sales, dtype: int64
# Best Selling Product:  A
# Average Daily Sales: 142.5

# %%
# !pip install pandas

import pandas as pd

class RetailSalesAnalyzer:
    def __init__(self):
        # Mount Google Drive if necessary
        from google.colab import drive
        drive.mount('/content/drive')

        # Adjust the file path if needed
        file_path = '/content/drive/My Drive/Colab Notebooks/retail_sales.csv'
        self.data = pd.read_csv(file_path)
        self.data['Date'] = pd.to_datetime(self.data['Date'])

    # ... rest of your class methods ...
# Out:
# Requirement already satisfied: pandas in /usr/local/lib/python3.10/dist-packages (2.0.3)
# Requirement already satisfied: python-dateutil>=2.8.2 in /usr/local/lib/python3.10/dist-packages (from pandas) (2.8.2)
# Requirement already satisfied: pytz>=2020.1 in /usr/local/lib/python3.10/dist-packages (from pandas) (2023.4)
# Requirement already satisfied: tzdata>=2022.1 in /usr/local/lib/python3.10/dist-packages (from pandas) (2024.1)
# Requirement already satisfied: numpy>=1.21.0 in /usr/local/lib/python3.10/dist-packages (from pandas) (1.25.2)
# Requirement already satisfied: six>=1.5 in /usr/local/lib/python3.10/dist-packages (from python-dateutil>=2.8.2->pandas) (1.16.0)

# %%
import pandas as pd
import matplotlib.pyplot as plt
class RetailSalesAnalyzer:
  def __init__(self):
    self.data = pd.read_csv('MyDrive/Colab Noteebooks/retail_sales.csv')
    self.data['Date'] = pd.to_datetime(self.data['Date'])
    self.data = data

  def data_clean(self):
    self.data.dropna(inplace=True)

class RetailSalesAnalyzer:

    def total_sales_per_product(self):
        return self.data.groupby('Product')['Sales'].sum()

# %%
def best_selling_product(self):
  return self.total_sales_per_product().sort_values(ascending=False).index[0]

# %%
def average_daily_sales(self):
  return self.data['Sales'].mean()

# %%
def plot_sales_trend(self):
  self.data.groupby('Date')['Sales'].sum().plot(kind='line')
  plt.title('Sales Trend over Time')
  plt.xlabel('Date')
  plt.ylabel('Total Sales')
  plt.show()

# %%
def plot_sales_per_product(self):
  self.total_sales_per_product().plot(kind='bar')
  plt.title('Sales per Product')
  plt.xlabel('Product')
  plt.ylabel('Total Sales')
  plt.show()

# %%
import pandas as pd
import matplotlib.pyplot as plt

class RetailSalesAnalyzer:
    def __init__(self, data):  # Add an initializer to set the 'data' attribute
        self.data = data

    def total_sales_per_product(self):
        return self.data.groupby('Product')['Sales'].sum()

    def best_selling_product(self):
        return self.total_sales_per_product().sort_values(ascending=False).index[0]

    def average_daily_sales(self):
        return self.data['Sales'].mean()

    def plot_sales_trend(self):
        self.data.groupby('Date')['Sales'].sum().plot(kind='line')
        plt.title('Sales Trend over Time')
        plt.xlabel('Date')
        plt.ylabel('Total Sales')
        plt.show()

    def plot_sales_per_product(self):
        self.total_sales_per_product().plot(kind='bar')
        plt.title('Sales per Product')
        plt.xlabel('Product')
        plt.ylabel('Total Sales')
        plt.show()

# %%
# !pip install pandas
import pandas as pd

class RetailSalesAnalyzer:
  def __init__(self):
    # Mount Google Drive if you are using Colab
    from google.colab import drive
    drive.mount('/content/drive')

    # Correct the file path if necessary, and make sure the file exists in the specified location
    # Example:
    self.data = pd.read_csv('/content/drive/MyDrive/Colab Notebooks/retail_sales.csv')
    self.data['Date'] = pd.to_datetime(self.data['Date'])

  # ... rest of your class methods ...
# Out:
# Requirement already satisfied: pandas in /usr/local/lib/python3.10/dist-packages (2.0.3)
# Requirement already satisfied: python-dateutil>=2.8.2 in /usr/local/lib/python3.10/dist-packages (from pandas) (2.8.2)
# Requirement already satisfied: pytz>=2020.1 in /usr/local/lib/python3.10/dist-packages (from pandas) (2023.4)
# Requirement already satisfied: tzdata>=2022.1 in /usr/local/lib/python3.10/dist-packages (from pandas) (2024.1)
# Requirement already satisfied: numpy>=1.21.0 in /usr/local/lib/python3.10/dist-packages (from pandas) (1.25.2)
# Requirement already satisfied: six>=1.5 in /usr/local/lib/python3.10/dist-packages (from python-dateutil>=2.8.2->pandas) (1.16.0)

# %%
import pandas as pd
import matplotlib.pyplot as plt

# Sample DataFrame (replace with your actual data)
data = pd.DataFrame({
    'Date': ['2023-01-01', '2023-01-01', '2023-01-02', '2023-01-02'],
    'Product': ['A', 'B', 'A', 'C'],
    'Sales': [100, 150, 120, 200]
})

class RetailSalesAnalyzer:
    def __init__(self, data):  # Add an initializer to set the 'data' attribute
        self.data = data

    def total_sales_per_product(self):
        return self.data.groupby('Product')['Sales'].sum()

    def best_selling_product(self):
        return self.total_sales_per_product().sort_values(ascending=False).index[0]

    def average_daily_sales(self):
        return self.data['Sales'].mean()

    def plot_sales_trend(self):
        self.data.groupby('Date')['Sales'].sum().plot(kind='line')
        plt.title('Sales Trend over Time')
        plt.xlabel('Date')
        plt.ylabel('Total Sales')
        plt.show()

    def plot_sales_per_product(self):
        self.total_sales_per_product().plot(kind='bar')
        plt.title('Sales per Product')
        plt.xlabel('Product')
        plt.ylabel('Total Sales')
        plt.show()

# Create an instance of the analyzer, passing the data
analyzer = RetailSalesAnalyzer(data)  # Pass the DataFrame to the constructor

print('Total Sales per Product: ',analyzer.total_sales_per_product())
print('Best Selling Product:',analyzer.best_selling_product())
print('Average Daily Sales:',analyzer.average_daily_sales())
analyzer.plot_sales_per_product()
analyzer.plot_sales_trend()
# Out:
# Total Sales per Product:  Product
# A    220
# B    150
# C    200
# Name: Sales, dtype: int64
# Best Selling Product: A
# Average Daily Sales: 142.5
